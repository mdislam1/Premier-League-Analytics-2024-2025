# %% [markdown]
# # Comprehensive Performance Analysis of Premier League Teams: Insights and Trends for the 2024-2025 Season
#
# This project provides an in-depth statistical and visual analysis of team performance in the Premier League for the 2024-2025 season. Leveraging advanced metrics such as expected goals (xG), goal difference, win percentages, and form trends, the study uncovers key insights into team strengths, weaknesses, and overall competitiveness. By exploring correlations, distributions, and performance trends, this analysis aims to identify standout teams, evaluate tactical efficiencies, and highlight factors contributing to success or failure. The findings are supported by intuitive visualizations, including heatmaps, scatter plots, and distribution charts, making it a valuable resource for football analysts, coaches, and enthusiasts seeking to understand the dynamics of the 2024-2025 Premier League season.

# %%
# Install the required libraries:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the HTML tables from the webpage
tables = pd.read_html("https://fbref.com/en/comps/9/Premier-League-Stats#all_rank_key")
df = tables[0]  # Replace 0 with the index of the table you want

# %%
# Display the first few rows
df.head()
# Out:
#    Rk            Squad  MP   W  D  L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0   1        Liverpool  26  18  7  1  62  26  36   61    2.35  58.7  23.9
# 1   2          Arsenal  25  15  8  2  51  22  29   53    2.12  40.0  21.4
# 2   3  Nott'ham Forest  25  14  5  6  41  29  12   47    1.88  32.1  28.8
# 3   4  Manchester City  25  13  5  7  52  35  17   44    1.76  46.0  34.6
# 4   5      Bournemouth  25  12  7  6  44  29  15   43    1.72  46.8  32.0
#
#     xGD  xGD/90     Last 5  Attendance       Top Team Scorer  \
# 0  34.8    1.34  W W D W D       60286    Mohamed Salah - 24
# 1  18.6    0.74  W D W W W       60276       Kai Havertz - 9
# 2   3.3    0.13  D W L W L       30056       Chris Wood - 18
# 3  11.4    0.46  D W W L W       52905   Erling Haaland - 19
# 4  14.8    0.59  D W W L W       11213  Justin Kluivert - 11
#
#           Goalkeeper  Notes
# 0            Alisson    NaN
# 1         David Raya    NaN
# 2          Matz Sels    NaN
# 3            Ederson    NaN
# 4  Kepa Arrizabalaga    NaN

# %%
# Create a copy of the DataFrame
df_copy = df.copy()

# %% [markdown]
# ## Data Cleaning and Preprocessing for Analysis

# %%
# Drop the Notes Column
df.drop(columns=['Notes'], inplace=True)

# %%
# Rename columns
df.columns = df.columns.str.strip().str.lower()

column_name_mapping = {
    'rk': 'rank',
    'squad': 'team',
    'mp': 'matches_played',
    'w': 'wins',
    'd': 'draws',
    'l': 'losses',
    'gf': 'goals_for',
    'ga': 'goals_against',
    'gd': 'goal_difference',
    'pts': 'points',
    'pts_mp': 'points_per_match',
    'xg': 'expected_goals',
    'xga': 'expected_goals_against',
    'xgd': 'expected_goal_difference',
    'xgd_90': 'expected_goal_difference_per_90',
    'last 5': 'last_five_matches',
    'attendance': 'attendance_per_game',
    'top team scorer': 'top_scorer',
    'goalkeeper': 'main_goalkeeper'
}

df.rename(columns=column_name_mapping, inplace=True)
df.columns
# Out:
# Index(['rank', 'team', 'matches_played', 'wins', 'draws', 'losses',
#        'goals_for', 'goals_against', 'goal_difference', 'points', 'pts/mp',
#        'expected_goals', 'expected_goals_against', 'expected_goal_difference',
#        'xgd/90', 'last_five_matches', 'attendance_per_game', 'top_scorer',
#        'main_goalkeeper'],
#       dtype='object')

# %%
# Display the first few rows
df.head()
# Out:
#    rank             team  matches_played  wins  draws  losses  goals_for  \
# 0     1        Liverpool              26    18      7       1         62
# 1     2          Arsenal              25    15      8       2         51
# 2     3  Nott'ham Forest              25    14      5       6         41
# 3     4  Manchester City              25    13      5       7         52
# 4     5      Bournemouth              25    12      7       6         44
#
#    goals_against  goal_difference  points  pts/mp  expected_goals  \
# 0             26               36      61    2.35            58.7
# 1             22               29      53    2.12            40.0
# 2             29               12      47    1.88            32.1
# 3             35               17      44    1.76            46.0
# 4             29               15      43    1.72            46.8
#
#    expected_goals_against  expected_goal_difference  xgd/90 last_five_matches  \
# 0                    23.9                      34.8    1.34         W W D W D
# 1                    21.4                      18.6    0.74         W D W W W
# 2                    28.8                       3.3    0.13         D W L W L
# 3                    34.6                      11.4    0.46         D W W L W
# 4                    32.0                      14.8    0.59         D W W L W
#
#    attendance_per_game            top_scorer    main_goalkeeper
# 0                60286    Mohamed Salah - 24            Alisson
# 1                60276       Kai Havertz - 9         David Raya
# 2                30056       Chris Wood - 18          Matz Sels
# 3                52905   Erling Haaland - 19            Ederson
# 4                11213  Justin Kluivert - 11  Kepa Arrizabalaga

# %%
# Check for missing values
df.isnull().sum()
# Out:
# rank                        0
# team                        0
# matches_played              0
# wins                        0
# draws                       0
# losses                      0
# goals_for                   0
# goals_against               0
# goal_difference             0
# points                      0
# pts/mp                      0
# expected_goals              0
# expected_goals_against      0
# expected_goal_difference    0
# xgd/90                      0
# last_five_matches           0
# attendance_per_game         0
# top_scorer                  0
# main_goalkeeper             0
# dtype: int64

# %%
# Check data types
df.dtypes
# Out:
# rank                          int64
# team                         object
# matches_played                int64
# wins                          int64
# draws                         int64
# losses                        int64
# goals_for                     int64
# goals_against                 int64
# goal_difference               int64
# points                        int64
# pts/mp                      float64
# expected_goals              float64
# expected_goals_against      float64
# expected_goal_difference    float64
# xgd/90                      float64
# last_five_matches            object
# attendance_per_game           int64
# top_scorer                   object
# main_goalkeeper              object
# dtype: object

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Convert 'last_five_matches' to a categorical column
df['last_five_matches'] = df['last_five_matches'].astype('category')

# %%
# Ensure numeric columns are of type float or int
numeric_cols = ['matches_played', 'wins', 'draws', 'losses', 'goals_for', 'goals_against', 
                'goal_difference', 'points', 'pts/mp', 'expected_goals', 'expected_goals_against', 
                'expected_goal_difference', 'xgd/90', 'attendance_per_game']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
# Remove leading/trailing whitespace and replace spaces with underscores
df['team'] = df['team'].str.strip().str.replace(' ', '_')

# %%
# Standardize 'top_scorer' and 'main_goalkeeper' columns
df['top_scorer'] = df['top_scorer'].str.strip()
df['main_goalkeeper'] = df['main_goalkeeper'].str.strip()

# %% [markdown]
# ## Comprehensive Feature Engineering for Analysis

# %% [markdown]
# ### Performance Metrics

# %%
# Calculate win percentage as (wins / matches_played) * 100
df['win_percentage'] = (df['wins'] / df['matches_played']) * 100

# %%
# Calculate loss percentage as (losses / matches_played) * 100
df['loss_percentage'] = (df['losses'] / df['matches_played']) * 100

# %%
# Calculate draw percentage as (draws / matches_played) * 100
df['draw_percentage'] = (df['draws'] / df['matches_played']) * 100

# %%
# Calculate goal difference per match as goal_difference / matches_played
df['goal_difference_per_match'] = df['goal_difference'] / df['matches_played']

# %%
# Calculate goals for per match as goals_for / matches_played
df['goals_for_per_match'] = df['goals_for'] / df['matches_played']

# %%
# Calculate goals against per match as goals_against / matches_played
df['goals_against_per_match'] = df['goals_against'] / df['matches_played']

# %%
# Display the first few rows
df.head()
# Out:
#    rank             team  matches_played  wins  draws  losses  goals_for  \
# 0     1        Liverpool              26    18      7       1         62
# 1     2          Arsenal              25    15      8       2         51
# 2     3  Nott'ham_Forest              25    14      5       6         41
# 3     4  Manchester_City              25    13      5       7         52
# 4     5      Bournemouth              25    12      7       6         44
#
#    goals_against  goal_difference  points  ...  last_five_matches  \
# 0             26               36      61  ...          W W D W D
# 1             22               29      53  ...          W D W W W
# 2             29               12      47  ...          D W L W L
# 3             35               17      44  ...          D W W L W
# 4             29               15      43  ...          D W W L W
#
#    attendance_per_game            top_scorer    main_goalkeeper  \
# 0                60286    Mohamed Salah - 24            Alisson
# 1                60276       Kai Havertz - 9         David Raya
# 2                30056       Chris Wood - 18          Matz Sels
# 3                52905   Erling Haaland - 19            Ederson
# 4                11213  Justin Kluivert - 11  Kepa Arrizabalaga
#
#    win_percentage loss_percentage  draw_percentage goal_difference_per_match  \
# 0       69.230769        3.846154        26.923077                  1.384615
# 1       60.000000        8.000000        32.000000                  1.160000
# 2       56.000000       24.000000        20.000000                  0.480000
# 3       52.000000       28.000000        20.000000                  0.680000
# 4       48.000000       24.000000        28.000000                  0.600000
#
#   goals_for_per_match  goals_against_per_match
# 0            2.384615                     1.00
# 1            2.040000                     0.88
# 2            1.640000                     1.16
# 3            2.080000                     1.40
# 4            1.760000                     1.16
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Expected Performance Metrics

# %%
# Calculate expected goal difference per match as expected_goal_difference / matches_played
df['expected_goal_difference_per_match'] = df['expected_goal_difference'] / df['matches_played']

# %%
# Calculate expected goals for per match as expected_goals / matches_played
df['expected_goals_for_per_match'] = df['expected_goals'] / df['matches_played']

# %%
# Calculate expected goals against per match as expected_goals_against / matches_played
df['expected_goals_against_per_match'] = df['expected_goals_against'] / df['matches_played']

# %%
# Calculate xG efficiency as goals_for / expected_goals
df['xg_efficiency'] = df['goals_for'] / df['expected_goals']

# %%
# Calculate xGA efficiency as goals_against / expected_goals_against
df['xga_efficiency'] = df['goals_against'] / df['expected_goals_against']

# %%
# Display the first few rows
df.head()
# Out:
#    rank             team  matches_played  wins  draws  losses  goals_for  \
# 0     1        Liverpool              26    18      7       1         62
# 1     2          Arsenal              25    15      8       2         51
# 2     3  Nott'ham_Forest              25    14      5       6         41
# 3     4  Manchester_City              25    13      5       7         52
# 4     5      Bournemouth              25    12      7       6         44
#
#    goals_against  goal_difference  points  ...  loss_percentage  \
# 0             26               36      61  ...         3.846154
# 1             22               29      53  ...         8.000000
# 2             29               12      47  ...        24.000000
# 3             35               17      44  ...        28.000000
# 4             29               15      43  ...        24.000000
#
#    draw_percentage  goal_difference_per_match  goals_for_per_match  \
# 0        26.923077                   1.384615             2.384615
# 1        32.000000                   1.160000             2.040000
# 2        20.000000                   0.480000             1.640000
# 3        20.000000                   0.680000             2.080000
# 4        28.000000                   0.600000             1.760000
#
#    goals_against_per_match expected_goal_difference_per_match  \
# 0                     1.00                           1.338462
# 1                     0.88                           0.744000
# 2                     1.16                           0.132000
# 3                     1.40                           0.456000
# 4                     1.16                           0.592000
#
#    expected_goals_for_per_match expected_goals_against_per_match  \
# 0                      2.257692                         0.919231
# 1                      1.600000                         0.856000
# 2                      1.284000                         1.152000
# 3                      1.840000                         1.384000
# 4                      1.872000                         1.280000
#
#   xg_efficiency  xga_efficiency
# 0      1.056218        1.087866
# 1      1.275000        1.028037
# 2      1.277259        1.006944
# 3      1.130435        1.011561
# 4      0.940171        0.906250
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Form and Consistency Metrics

# %%
# Count the number of wins in the last 5 matches
df['recent_wins'] = df['last_five_matches'].str.count('W')

# %%
# Count the number of draws in the last 5 matches
df['recent_draws'] = df['last_five_matches'].str.count('D')

# %%
# Count the number of losses in the last 5 matches
df['recent_losses'] = df['last_five_matches'].str.count('L')

# %%
# Calculate form points as (recent_wins * 3) + (recent_draws * 1)
df['form_points'] = (df['recent_wins'] * 3) + (df['recent_draws'] * 1)

# %%
# Calculate consistency score as the standard deviation of points per match
df['consistency_score'] = df.groupby('team')['points'].transform('std')

# %%
# Display the first few rows
df.head()
# Out:
#    rank             team  matches_played  wins  draws  losses  goals_for  \
# 0     1        Liverpool              26    18      7       1         62
# 1     2          Arsenal              25    15      8       2         51
# 2     3  Nott'ham_Forest              25    14      5       6         41
# 3     4  Manchester_City              25    13      5       7         52
# 4     5      Bournemouth              25    12      7       6         44
#
#    goals_against  goal_difference  points  ...  \
# 0             26               36      61  ...
# 1             22               29      53  ...
# 2             29               12      47  ...
# 3             35               17      44  ...
# 4             29               15      43  ...
#
#    expected_goal_difference_per_match  expected_goals_for_per_match  \
# 0                            1.338462                      2.257692
# 1                            0.744000                      1.600000
# 2                            0.132000                      1.284000
# 3                            0.456000                      1.840000
# 4                            0.592000                      1.872000
#
#    expected_goals_against_per_match  xg_efficiency  xga_efficiency  \
# 0                          0.919231       1.056218        1.087866
# 1                          0.856000       1.275000        1.028037
# 2                          1.152000       1.277259        1.006944
# 3                          1.384000       1.130435        1.011561
# 4                          1.280000       0.940171        0.906250
#
#   recent_wins  recent_draws recent_losses form_points  consistency_score
# 0           3             2             0          11                NaN
# 1           4             1             0          13                NaN
# 2           2             1             2           7                NaN
# 3           3             1             1          10                NaN
# 4           3             1             1          10                NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Attendance Metrics

# %%
# Use attendance_per_game as the average attendance
df['average_attendance'] = df['attendance_per_game']

# %%
# Calculate attendance ratio as attendance_per_game / max_attendance
max_attendance = df['attendance_per_game'].max()
df['attendance_ratio'] = df['attendance_per_game'] / max_attendance

# %%
# Display the first few rows
df.head()
# Out:
#    rank             team  matches_played  wins  draws  losses  goals_for  \
# 0     1        Liverpool              26    18      7       1         62
# 1     2          Arsenal              25    15      8       2         51
# 2     3  Nott'ham_Forest              25    14      5       6         41
# 3     4  Manchester_City              25    13      5       7         52
# 4     5      Bournemouth              25    12      7       6         44
#
#    goals_against  goal_difference  points  ...  \
# 0             26               36      61  ...
# 1             22               29      53  ...
# 2             29               12      47  ...
# 3             35               17      44  ...
# 4             29               15      43  ...
#
#    expected_goals_against_per_match  xg_efficiency  xga_efficiency  \
# 0                          0.919231       1.056218        1.087866
# 1                          0.856000       1.275000        1.028037
# 2                          1.152000       1.277259        1.006944
# 3                          1.384000       1.130435        1.011561
# 4                          1.280000       0.940171        0.906250
#
#    recent_wins  recent_draws recent_losses  form_points consistency_score  \
# 0            3             2             0           11               NaN
# 1            4             1             0           13               NaN
# 2            2             1             2            7               NaN
# 3            3             1             1           10               NaN
# 4            3             1             1           10               NaN
#
#   average_attendance  attendance_ratio
# 0              60286          0.817770
# 1              60276          0.817634
# 2              30056          0.407705
# 3              52905          0.717648
# 4              11213          0.152103
#
# [5 rows x 37 columns]

# %% [markdown]
# ### Top Scorer Metrics

# %%
# Extract the number of goals scored by the top scorer
df['top_scorer_goals'] = df['top_scorer'].str.extract(r'(\d+)').astype(float)

# %%
# Calculate top scorer contribution as top_scorer_goals / goals_for
df['top_scorer_contribution'] = df['top_scorer_goals'] / df['goals_for']

# %%
# Display the first few rows
df.head()
# Out:
#    rank             team  matches_played  wins  draws  losses  goals_for  \
# 0     1        Liverpool              26    18      7       1         62
# 1     2          Arsenal              25    15      8       2         51
# 2     3  Nott'ham_Forest              25    14      5       6         41
# 3     4  Manchester_City              25    13      5       7         52
# 4     5      Bournemouth              25    12      7       6         44
#
#    goals_against  goal_difference  points  ...  xga_efficiency  recent_wins  \
# 0             26               36      61  ...        1.087866            3
# 1             22               29      53  ...        1.028037            4
# 2             29               12      47  ...        1.006944            2
# 3             35               17      44  ...        1.011561            3
# 4             29               15      43  ...        0.906250            3
#
#    recent_draws  recent_losses  form_points consistency_score  \
# 0             2              0           11               NaN
# 1             1              0           13               NaN
# 2             1              2            7               NaN
# 3             1              1           10               NaN
# 4             1              1           10               NaN
#
#    average_attendance attendance_ratio top_scorer_goals  \
# 0               60286         0.817770             24.0
# 1               60276         0.817634              9.0
# 2               30056         0.407705             18.0
# 3               52905         0.717648             19.0
# 4               11213         0.152103             11.0
#
#    top_scorer_contribution
# 0                 0.387097
# 1                 0.176471
# 2                 0.439024
# 3                 0.365385
# 4                 0.250000
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Categorical Features

# %%
# Categorize teams into tiers (Top, Mid, Bottom) based on points
df['team_tier'] = pd.cut(df['points'], bins=[0, 30, 50, 100], labels=['Bottom', 'Mid', 'Top'])

# %%
# Display the first few rows
df.head()
# Out:
#    rank             team  matches_played  wins  draws  losses  goals_for  \
# 0     1        Liverpool              26    18      7       1         62
# 1     2          Arsenal              25    15      8       2         51
# 2     3  Nott'ham_Forest              25    14      5       6         41
# 3     4  Manchester_City              25    13      5       7         52
# 4     5      Bournemouth              25    12      7       6         44
#
#    goals_against  goal_difference  points  ...  recent_wins  recent_draws  \
# 0             26               36      61  ...            3             2
# 1             22               29      53  ...            4             1
# 2             29               12      47  ...            2             1
# 3             35               17      44  ...            3             1
# 4             29               15      43  ...            3             1
#
#    recent_losses  form_points  consistency_score average_attendance  \
# 0              0           11                NaN              60286
# 1              0           13                NaN              60276
# 2              2            7                NaN              30056
# 3              1           10                NaN              52905
# 4              1           10                NaN              11213
#
#    attendance_ratio top_scorer_goals top_scorer_contribution  team_tier
# 0          0.817770             24.0                0.387097        Top
# 1          0.817634              9.0                0.176471        Top
# 2          0.407705             18.0                0.439024        Mid
# 3          0.717648             19.0                0.365385        Mid
# 4          0.152103             11.0                0.250000        Mid
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Statistical Analysis and Visualization

# %%
# Set visual style
sns.set(style="whitegrid", palette="pastel")
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Calculate summary statistics for numeric columns
summary_stats = df.describe()
summary_stats
# Out:
#            rank  matches_played       wins     draws     losses  goals_for  \
# count  20.00000       20.000000  20.000000  20.00000  20.000000  20.000000
# mean   10.50000       25.100000   9.350000   6.40000   9.350000  37.950000
# std     5.91608        0.307794   4.132987   2.18608   4.847951  11.184929
# min     1.00000       25.000000   2.000000   3.00000   1.000000  19.000000
# 25%     5.75000       25.000000   7.000000   5.00000   6.000000  28.750000
# 50%    10.50000       25.000000   9.500000   6.50000   8.500000  38.000000
# 75%    15.25000       25.000000  12.000000   8.25000  12.250000  44.750000
# max    20.00000       26.000000  18.000000  10.00000  20.000000  62.000000
#
#        goals_against  goal_difference     points     pts/mp  ...  \
# count       20.00000        20.000000  20.000000  20.000000  ...
# mean        37.95000         0.000000  34.450000   1.370500  ...
# std          9.95503        19.270922  12.926818   0.506666  ...
# min         22.00000       -38.000000   9.000000   0.360000  ...
# 25%         31.75000        -9.750000  28.500000   1.140000  ...
# 50%         35.00000         0.500000  35.500000   1.420000  ...
# 75%         43.25000        12.250000  43.000000   1.720000  ...
# max         57.00000        36.000000  61.000000   2.350000  ...
#
#        xga_efficiency  recent_wins  recent_draws  recent_losses  form_points  \
# count       20.000000    20.000000     20.000000      20.000000    20.000000
# mean         1.038888     2.100000      0.750000       2.150000     7.050000
# std          0.110062     1.165287      0.966546       1.348488     3.425523
# min          0.880952     0.000000      0.000000       0.000000     1.000000
# 25%          0.962290     1.000000      0.000000       1.000000     4.000000
# 50%          1.019799     2.000000      1.000000       2.000000     7.000000
# 75%          1.087890     3.000000      1.000000       3.000000     9.250000
# max          1.313869     4.000000      4.000000       4.000000    13.000000
#
#        consistency_score  average_attendance  attendance_ratio  \
# count                0.0           20.000000         20.000000
# mean                 NaN        40526.250000          0.549732
# std                  NaN        16847.872972          0.228539
# min                  NaN        11213.000000          0.152103
# 25%                  NaN        29981.000000          0.406687
# 50%                  NaN        35176.000000          0.477157
# 75%                  NaN        54747.750000          0.742644
# max                  NaN        73720.000000          1.000000
#
#        top_scorer_goals  top_scorer_contribution
# count         20.000000                20.000000
# mean          11.150000                 0.289359
# std            5.284287                 0.093352
# min            3.000000                 0.157895
# 25%            6.750000                 0.212438
# 50%           10.500000                 0.288936
# 75%           14.000000                 0.368866
# max           24.000000                 0.439024
#
# [8 rows x 35 columns]

# %%
# Compute the correlation matrix for numeric columns
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                                         rank  matches_played      wins  \
# rank                                1.000000       -0.317940 -0.971865
# matches_played                     -0.317940        1.000000  0.384774
# wins                               -0.971865        0.384774  1.000000
# draws                              -0.244173        0.250306  0.158447
# losses                              0.918456       -0.377409 -0.899542
# goals_for                          -0.872939        0.353155  0.904401
# goals_against                       0.846738       -0.170051 -0.839989
# goal_difference                    -0.944068        0.292818  0.958843
# points                             -0.973472        0.411392  0.985961
# pts/mp                             -0.976875        0.374280  0.985666
# expected_goals                     -0.800813        0.416070  0.850083
# expected_goals_against              0.860446       -0.320640 -0.859060
# expected_goal_difference           -0.922363        0.411171  0.949813
# xgd/90                             -0.923530        0.400274  0.949390
# attendance_per_game                -0.138542        0.214747  0.285019
# win_percentage                     -0.974511        0.351176  0.999281
# loss_percentage                     0.917838       -0.386323 -0.898888
# draw_percentage                    -0.234179        0.209242  0.145137
# goal_difference_per_match          -0.944695        0.284677  0.957688
# goals_for_per_match                -0.872717        0.307636  0.899967
# goals_against_per_match             0.852630       -0.208156 -0.847701
# expected_goal_difference_per_match -0.923803        0.400628  0.949443
# expected_goals_for_per_match       -0.801673        0.366137  0.846852
# expected_goals_against_per_match    0.860963       -0.354465 -0.861521
# xg_efficiency                      -0.398366       -0.024897  0.372948
# xga_efficiency                      0.115552        0.362512 -0.104761
# recent_wins                        -0.564951       -0.176090  0.549689
# recent_draws                       -0.372773        0.796117  0.378789
# recent_losses                       0.755389       -0.418460 -0.746512
# form_points                        -0.681734        0.044926  0.667856
# consistency_score                        NaN             NaN       NaN
# average_attendance                 -0.138542        0.214747  0.285019
# attendance_ratio                   -0.138542        0.214747  0.285019
# top_scorer_goals                   -0.706249        0.443324  0.730074
# top_scorer_contribution            -0.238127        0.243079  0.218531
#
#                                        draws    losses  goals_for  \
# rank                               -0.244173  0.918456  -0.872939
# matches_played                      0.250306 -0.377409   0.353155
# wins                                0.158447 -0.899542   0.904401
# draws                               1.000000 -0.570117  -0.012054
# losses                             -0.570117  1.000000  -0.743165
# goals_for                          -0.012054 -0.743165   1.000000
# goals_against                      -0.415007  0.892452  -0.660835
# goal_difference                     0.207389 -0.892362   0.921781
# points                              0.321089 -0.959223   0.865432
# pts/mp                              0.317706 -0.959802   0.863635
# expected_goals                      0.039397 -0.716064   0.889642
# expected_goals_against             -0.471619  0.924677  -0.688121
# expected_goal_difference            0.276484 -0.908306   0.880289
# xgd/90                              0.276697 -0.908734   0.879938
# attendance_per_game                -0.181290 -0.147602   0.273524
# win_percentage                      0.153036 -0.898622   0.902573
# loss_percentage                    -0.572442  0.999925  -0.742173
# draw_percentage                     0.999094 -0.560968  -0.025560
# goal_difference_per_match           0.208185 -0.892253   0.920070
# goals_for_per_match                -0.023626 -0.737057   0.998752
# goals_against_per_match            -0.423815  0.900579  -0.667863
# expected_goal_difference_per_match  0.277189 -0.908978   0.879160
# expected_goals_for_per_match        0.027151 -0.710958   0.888848
# expected_goals_against_per_match   -0.476415  0.926791  -0.691097
# xg_efficiency                      -0.064830 -0.290293   0.498695
# xga_efficiency                      0.065120  0.082962  -0.050288
# recent_wins                         0.334705 -0.630730   0.464789
# recent_draws                        0.323818 -0.418400   0.290890
# recent_losses                      -0.521334  0.844935  -0.610143
# form_points                         0.432946 -0.761738   0.556410
# consistency_score                        NaN       NaN        NaN
# average_attendance                 -0.181290 -0.147602   0.273524
# attendance_ratio                   -0.181290 -0.147602   0.273524
# top_scorer_goals                   -0.087477 -0.554812   0.737456
# top_scorer_contribution            -0.026502 -0.158919   0.170208
#
#                                     goals_against  goal_difference    points  \
# rank                                     0.846738        -0.944068 -0.973472
# matches_played                          -0.170051         0.292818  0.411392
# wins                                    -0.839989         0.958843  0.985961
# draws                                   -0.415007         0.207389  0.321089
# losses                                   0.892452        -0.892362 -0.959223
# goals_for                               -0.660835         0.921781  0.865432
# goals_against                            1.000000        -0.900135 -0.875871
# goal_difference                         -0.900135         1.000000  0.954761
# points                                  -0.875871         0.954761  1.000000
# pts/mp                                  -0.883923         0.957877  0.999144
# expected_goals                          -0.667661         0.861254  0.822033
# expected_goals_against                   0.907089        -0.867975 -0.903737
# expected_goal_difference                -0.871105         0.960921  0.957785
# xgd/90                                  -0.873189         0.961795  0.957415
# attendance_per_game                     -0.228721         0.276908  0.242722
# win_percentage                          -0.846081         0.960928  0.984356
# loss_percentage                          0.890382        -0.890717 -0.958989
# draw_percentage                         -0.413404         0.198723  0.308169
# goal_difference_per_match               -0.901850         0.999893  0.953788
# goals_for_per_match                     -0.663568         0.922468  0.859222
# goals_against_per_match                  0.999211        -0.903806 -0.884758
# expected_goal_difference_per_match      -0.874090         0.961809  0.957549
# expected_goals_for_per_match            -0.673637         0.863881  0.816863
# expected_goals_against_per_match         0.901447        -0.866788 -0.906909
# xg_efficiency                           -0.188739         0.386944  0.346755
# xga_efficiency                           0.384538        -0.227833 -0.089470
# recent_wins                             -0.770840         0.667968  0.583846
# recent_draws                            -0.209225         0.276916  0.418083
# recent_losses                            0.816080        -0.775703 -0.804193
# form_points                             -0.845703         0.759819  0.713801
# consistency_score                             NaN              NaN       NaN
# average_attendance                      -0.228721         0.276908  0.242722
# attendance_ratio                        -0.228721         0.276908  0.242722
# top_scorer_goals                        -0.438069         0.654322  0.685469
# top_scorer_contribution                 -0.071247         0.135595  0.205126
#
#                                       pts/mp  ...  xga_efficiency  \
# rank                               -0.976875  ...        0.115552
# matches_played                      0.374280  ...        0.362512
# wins                                0.985666  ...       -0.104761
# draws                               0.317706  ...        0.065120
# losses                             -0.959802  ...        0.082962
# goals_for                           0.863635  ...       -0.050288
# goals_against                      -0.883923  ...        0.384538
# goal_difference                     0.957877  ...       -0.227833
# points                              0.999144  ...       -0.089470
# pts/mp                              1.000000  ...       -0.105908
# expected_goals                      0.816387  ...       -0.210238
# expected_goals_against             -0.906135  ...       -0.034459
# expected_goal_difference            0.955836  ...       -0.101841
# xgd/90                              0.956030  ...       -0.105018
# attendance_per_game                 0.236225  ...       -0.137679
# win_percentage                      0.985620  ...       -0.119093
# loss_percentage                    -0.959235  ...        0.077709
# draw_percentage                     0.306351  ...        0.048803
# goal_difference_per_match           0.957355  ...       -0.230604
# goals_for_per_match                 0.859429  ...       -0.068017
# goals_against_per_match            -0.891351  ...        0.366558
# expected_goal_difference_per_match  0.956161  ...       -0.105664
# expected_goals_for_per_match        0.813420  ...       -0.236183
# expected_goals_against_per_match   -0.907908  ...       -0.048908
# xg_efficiency                       0.354373  ...        0.333642
# xga_efficiency                     -0.105908  ...        1.000000
# recent_wins                         0.599849  ...       -0.370023
# recent_draws                        0.393623  ...        0.238833
# recent_losses                      -0.800490  ...        0.148566
# form_points                         0.723231  ...       -0.310232
# consistency_score                        NaN  ...             NaN
# average_attendance                  0.236225  ...       -0.137679
# attendance_ratio                    0.236225  ...       -0.137679
# top_scorer_goals                    0.675811  ...        0.122573
# top_scorer_contribution             0.197216  ...        0.200581
#
#                                     recent_wins  recent_draws  recent_losses  \
# rank                                  -0.564951     -0.372773       0.755389
# matches_played                        -0.176090      0.796117      -0.418460
# wins                                   0.549689      0.378789      -0.746512
# draws                                  0.334705      0.323818      -0.521334
# losses                                -0.630730     -0.418400       0.844935
# goals_for                              0.464789      0.290890      -0.610143
# goals_against                         -0.770840     -0.209225       0.816080
# goal_difference                        0.667968      0.276916      -0.775703
# points                                 0.583846      0.418083      -0.804193
# pts/mp                                 0.599849      0.393623      -0.800490
# expected_goals                         0.425960      0.313233      -0.592604
# expected_goals_against                -0.679897     -0.318311       0.815682
# expected_goal_difference               0.610602      0.350323      -0.778746
# xgd/90                                 0.613102      0.345553      -0.777487
# attendance_per_game                    0.066261      0.077725      -0.112969
# win_percentage                         0.562115      0.357539      -0.742019
# loss_percentage                       -0.624405     -0.427823       0.846222
# draw_percentage                        0.348479      0.290549      -0.509391
# goal_difference_per_match              0.669168      0.275012      -0.775375
# goals_for_per_match                    0.478888      0.259662      -0.599944
# goals_against_per_match               -0.756133     -0.242089       0.826927
# expected_goal_difference_per_match     0.613927      0.346061      -0.778565
# expected_goals_for_per_match           0.443509      0.277890      -0.582436
# expected_goals_against_per_match      -0.662741     -0.346569       0.821111
# xg_efficiency                          0.189932      0.044473      -0.196005
# xga_efficiency                        -0.370023      0.238833       0.148566
# recent_wins                            1.000000     -0.210283      -0.713421
# recent_draws                          -0.210283      1.000000      -0.535048
# recent_losses                         -0.713421     -0.535048       1.000000
# form_points                            0.961200      0.067559      -0.879039
# consistency_score                           NaN           NaN            NaN
# average_attendance                     0.066261      0.077725      -0.112969
# attendance_ratio                       0.066261      0.077725      -0.112969
# top_scorer_goals                       0.134192      0.368395      -0.380013
# top_scorer_contribution               -0.247075      0.262109       0.025639
#
#                                     form_points  consistency_score  \
# rank                                  -0.681734                NaN
# matches_played                         0.044926                NaN
# wins                                   0.667856                NaN
# draws                                  0.432946                NaN
# losses                                -0.761738                NaN
# goals_for                              0.556410                NaN
# goals_against                         -0.845703                NaN
# goal_difference                        0.759819                NaN
# points                                 0.713801                NaN
# pts/mp                                 0.723231                NaN
# expected_goals                         0.523088                NaN
# expected_goals_against                -0.783673                NaN
# expected_goal_difference               0.721987                NaN
# xgd/90                                 0.723192                NaN
# attendance_per_game                    0.089552                NaN
# win_percentage                         0.674541                NaN
# loss_percentage                       -0.757941                NaN
# draw_percentage                        0.437616                NaN
# goal_difference_per_match              0.760506                NaN
# goals_for_per_match                    0.561987                NaN
# goals_against_per_match               -0.839967                NaN
# expected_goal_difference_per_match     0.724178                NaN
# expected_goals_for_per_match           0.531025                NaN
# expected_goals_against_per_match      -0.774137                NaN
# xg_efficiency                          0.206380                NaN
# xga_efficiency                        -0.310232                NaN
# recent_wins                            0.961200                NaN
# recent_draws                           0.067559                NaN
# recent_losses                         -0.879039                NaN
# form_points                            1.000000                NaN
# consistency_score                           NaN                NaN
# average_attendance                     0.089552                NaN
# attendance_ratio                       0.089552                NaN
# top_scorer_goals                       0.240894                NaN
# top_scorer_contribution               -0.178192                NaN
#
#                                     average_attendance  attendance_ratio  \
# rank                                         -0.138542         -0.138542
# matches_played                                0.214747          0.214747
# wins                                          0.285019          0.285019
# draws                                        -0.181290         -0.181290
# losses                                       -0.147602         -0.147602
# goals_for                                     0.273524          0.273524
# goals_against                                -0.228721         -0.228721
# goal_difference                               0.276908          0.276908
# points                                        0.242722          0.242722
# pts/mp                                        0.236225          0.236225
# expected_goals                                0.290498          0.290498
# expected_goals_against                       -0.172030         -0.172030
# expected_goal_difference                      0.259191          0.259191
# xgd/90                                        0.256580          0.256580
# attendance_per_game                           1.000000          1.000000
# win_percentage                                0.279446          0.279446
# loss_percentage                              -0.148007         -0.148007
# draw_percentage                              -0.191653         -0.191653
# goal_difference_per_match                     0.274422          0.274422
# goals_for_per_match                           0.265744          0.265744
# goals_against_per_match                      -0.234316         -0.234316
# expected_goal_difference_per_match            0.256451          0.256451
# expected_goals_for_per_match                  0.283177          0.283177
# expected_goals_against_per_match             -0.176996         -0.176996
# xg_efficiency                                -0.014119         -0.014119
# xga_efficiency                               -0.137679         -0.137679
# recent_wins                                   0.066261          0.066261
# recent_draws                                  0.077725          0.077725
# recent_losses                                -0.112969         -0.112969
# form_points                                   0.089552          0.089552
# consistency_score                                  NaN               NaN
# average_attendance                            1.000000          1.000000
# attendance_ratio                              1.000000          1.000000
# top_scorer_goals                              0.073491          0.073491
# top_scorer_contribution                      -0.194959         -0.194959
#
#                                     top_scorer_goals  top_scorer_contribution
# rank                                       -0.706249                -0.238127
# matches_played                              0.443324                 0.243079
# wins                                        0.730074                 0.218531
# draws                                      -0.087477                -0.026502
# losses                                     -0.554812                -0.158919
# goals_for                                   0.737456                 0.170208
# goals_against                              -0.438069                -0.071247
# goal_difference                             0.654322                 0.135595
# points                                      0.685469                 0.205126
# pts/mp                                      0.675811                 0.197216
# expected_goals                              0.680577                 0.139074
# expected_goals_against                     -0.529064                -0.173610
# expected_goal_difference                    0.674749                 0.172770
# xgd/90                                      0.672093                 0.171715
# attendance_per_game                         0.073491                -0.194959
# win_percentage                              0.721202                 0.211380
# loss_percentage                            -0.555070                -0.160097
# draw_percentage                            -0.105721                -0.036807
# goal_difference_per_match                   0.649729                 0.132683
# goals_for_per_match                         0.725294                 0.159515
# goals_against_per_match                    -0.449776                -0.079395
# expected_goal_difference_per_match          0.670349                 0.169610
# expected_goals_for_per_match                0.667830                 0.126462
# expected_goals_against_per_match           -0.537257                -0.180039
# xg_efficiency                               0.355486                 0.173273
# xga_efficiency                              0.122573                 0.200581
# recent_wins                                 0.134192                -0.247075
# recent_draws                                0.368395                 0.262109
# recent_losses                              -0.380013                 0.025639
# form_points                                 0.240894                -0.178192
# consistency_score                                NaN                      NaN
# average_attendance                          0.073491                -0.194959
# attendance_ratio                            0.073491                -0.194959
# top_scorer_goals                            1.000000                 0.758393
# top_scorer_contribution                     0.758393                 1.000000
#
# [35 rows x 35 columns]

# %%
# Sort teams by points in descending order
top_teams = df.sort_values(by='points', ascending=False)
top_teams[['team', 'points']].head()
# Out:
#               team  points
# 0        Liverpool      61
# 1          Arsenal      53
# 2  Nott'ham_Forest      47
# 3  Manchester_City      44
# 4      Bournemouth      43

# %%
# Sort teams by points in ascending order
bottom_teams = df.sort_values(by='points', ascending=True)
bottom_teams[['team', 'points']].head()
# Out:
#               team  points
# 19     Southampton       9
# 17    Ipswich_Town      17
# 18  Leicester_City      17
# 16          Wolves      19
# 15        West_Ham      27

# %%
# Sort teams by win percentage in descending order
top_win_percentage = df.sort_values(by='win_percentage', ascending=False)
top_win_percentage[['team', 'win_percentage']].head()
# Out:
#               team  win_percentage
# 0        Liverpool       69.230769
# 1          Arsenal       60.000000
# 2  Nott'ham_Forest       56.000000
# 3  Manchester_City       52.000000
# 4      Bournemouth       48.000000

# %%
# Sort teams by goal difference in descending order
top_goal_diff = df.sort_values(by='goal_difference', ascending=False)
top_goal_diff[['team', 'goal_difference']].head()
# Out:
#               team  goal_difference
# 0        Liverpool               36
# 1          Arsenal               29
# 3  Manchester_City               17
# 4      Bournemouth               15
# 5          Chelsea               13

# %%
# Sort teams by expected goals in descending order
top_xg = df.sort_values(by='expected_goals', ascending=False)
top_xg[['team', 'expected_goals']].head()
# Out:
#                team  expected_goals
# 0         Liverpool            58.7
# 5           Chelsea            49.2
# 4       Bournemouth            46.8
# 3   Manchester_City            46.0
# 11        Tottenham            41.8

# %%
# Sort teams by expected goals against in ascending order
low_xga = df.sort_values(by='expected_goals_against', ascending=True)
low_xga[['team', 'expected_goals_against']].head()
# Out:
#               team  expected_goals_against
# 1          Arsenal                    21.4
# 0        Liverpool                    23.9
# 7           Fulham                    28.0
# 2  Nott'ham_Forest                    28.8
# 6    Newcastle_Utd                    31.3

# %%
# Sort teams by xG efficiency in descending order
top_xg_efficiency = df.sort_values(by='xg_efficiency', ascending=False)
top_xg_efficiency[['team', 'xg_efficiency']].head()
# Out:
#                team  xg_efficiency
# 16           Wolves       1.286765
# 2   Nott'ham_Forest       1.277259
# 1           Arsenal       1.275000
# 11        Tottenham       1.172249
# 3   Manchester_City       1.130435

# %%
# Sort teams by form points in descending order
top_form_points = df.sort_values(by='form_points', ascending=False)
top_form_points[['team', 'form_points']].head()
# Out:
#                team  form_points
# 13          Everton           13
# 1           Arsenal           13
# 0         Liverpool           11
# 3   Manchester_City           10
# 4       Bournemouth           10

# %%
# Sort teams by top scorer contribution in descending order
top_scorer_contribution = df.sort_values(by='top_scorer_contribution', ascending=False)
top_scorer_contribution[['team', 'top_scorer_contribution']].head()
# Out:
#                team  top_scorer_contribution
# 2   Nott'ham_Forest                 0.439024
# 17     Ipswich_Town                 0.434783
# 6     Newcastle_Utd                 0.404762
# 0         Liverpool                 0.387097
# 12   Crystal_Palace                 0.379310

# %%
# Sort teams by average attendance in descending order
top_attendance = df.sort_values(by='average_attendance', ascending=False)
top_attendance[['team', 'average_attendance']].head()
# Out:
#               team  average_attendance
# 14  Manchester_Utd               73720
# 15        West_Ham               62464
# 11       Tottenham               61339
# 0        Liverpool               60286
# 1          Arsenal               60276

# %%
# Sort teams by consistency score in ascending order (lower is better)
top_consistency = df.sort_values(by='consistency_score', ascending=True)
top_consistency[['team', 'consistency_score']].head()
# Out:
#               team  consistency_score
# 0        Liverpool                NaN
# 1          Arsenal                NaN
# 2  Nott'ham_Forest                NaN
# 3  Manchester_City                NaN
# 4      Bournemouth                NaN

# %%
# Sort teams by goal difference per match in descending order
top_gd_per_match = df.sort_values(by='goal_difference_per_match', ascending=False)
top_gd_per_match[['team', 'goal_difference_per_match']].head()
# Out:
#               team  goal_difference_per_match
# 0        Liverpool                   1.384615
# 1          Arsenal                   1.160000
# 3  Manchester_City                   0.680000
# 4      Bournemouth                   0.600000
# 5          Chelsea                   0.520000

# %%
# Plot a heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Plot the distribution of points
plt.figure(figsize=(10, 6))
sns.histplot(df['points'], kde=True, bins=10)
plt.title('Distribution of Points')
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of win percentage
plt.figure(figsize=(10, 6))
sns.histplot(df['win_percentage'], kde=True, bins=10)
plt.title('Distribution of Win Percentage')
plt.xlabel('Win Percentage')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of goal difference
plt.figure(figsize=(10, 6))
sns.histplot(df['goal_difference'], kde=True, bins=10)
plt.title('Distribution of Goal Difference')
plt.xlabel('Goal Difference')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of expected goals
plt.figure(figsize=(10, 6))
sns.histplot(df['expected_goals'], kde=True, bins=10)
plt.title('Distribution of Expected Goals (xG)')
plt.xlabel('Expected Goals (xG)')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of expected goals against
plt.figure(figsize=(10, 6))
sns.histplot(df['expected_goals_against'], kde=True, bins=10)
plt.title('Distribution of Expected Goals Against (xGA)')
plt.xlabel('Expected Goals Against (xGA)')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of xG efficiency
plt.figure(figsize=(10, 6))
sns.histplot(df['xg_efficiency'], kde=True, bins=10)
plt.title('Distribution of xG Efficiency')
plt.xlabel('xG Efficiency')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of form points
plt.figure(figsize=(10, 6))
sns.histplot(df['form_points'], kde=True, bins=10)
plt.title('Distribution of Form Points')
plt.xlabel('Form Points')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of top scorer contribution
plt.figure(figsize=(10, 6))
sns.histplot(df['top_scorer_contribution'], kde=True, bins=10)
plt.title('Distribution of Top Scorer Contribution')
plt.xlabel('Top Scorer Contribution')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of average attendance
plt.figure(figsize=(10, 6))
sns.histplot(df['average_attendance'], kde=True, bins=10)
plt.title('Distribution of Average Attendance')
plt.xlabel('Average Attendance')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of consistency score
plt.figure(figsize=(10, 6))
sns.histplot(df['consistency_score'], kde=True, bins=10)
plt.title('Distribution of Consistency Score')
plt.xlabel('Consistency Score')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the distribution of goal difference per match
plt.figure(figsize=(10, 6))
sns.histplot(df['goal_difference_per_match'], kde=True, bins=10)
plt.title('Distribution of Goal Difference per Match')
plt.xlabel('Goal Difference per Match')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot points vs. expected goals
plt.figure(figsize=(10, 6))
sns.scatterplot(x='expected_goals', y='points', data=df)
plt.title('Points vs. Expected Goals (xG)')
plt.xlabel('Expected Goals (xG)')
plt.ylabel('Points')
plt.show()

# %%
# Plot goal difference vs. win percentage
plt.figure(figsize=(10, 6))
sns.scatterplot(x='goal_difference', y='win_percentage', data=df)
plt.title('Goal Difference vs. Win Percentage')
plt.xlabel('Goal Difference')
plt.ylabel('Win Percentage')
plt.show()
